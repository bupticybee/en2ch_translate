# %%
import pandas as pd

# %%
predict = open('eval/align_word_deep/2_6949_predict',encoding='utf-8').readlines()
target = open('eval/align_word_deep/2_6949_target',encoding='utf-8').readlines()
source = open('eval/align_word_deep/2_6949_source',encoding='utf-8').readlines()

# %%
dframe = pd.DataFrame(
{
        'predict':predict,
        'target':target,
        'source':source,
    })

# %%
dframe
# Out:
#                                                  predict  \
# 0      <unk> 和 <unk> 都 是 <unk> 的 。                   ...
# 1      ( iii ) <unk> <unk> 的 地方 的 <unk> <unk> ; 及    ...
# 2      此 警报 表示 远程 用户 正试图 使用 <unk> 、 <unk> <unk> 远程 <u...
# 3      <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk...
# 4      ( e ) 以 利息 或 根据 投资 的 方式 而 收取 的 所有 款项 ， 以及 基金 的...
# 5      <unk> <unk> <unk> <unk> 皮肤 <unk> 修复 修复        ...
# 6      <unk> ， <unk> <unk> <unk> <unk> <unk> <unk> <u...
# 7      而且 ， 你 的 慷慨 <unk> <unk> ， 你 的 <unk> <unk> ， 你 ...
# 8      而 在 左边 ， 有 一个 进化 的 进化 ，                       ...
# 9      如果 <unk> 的 任命 ， 他 在 任期 内 2 月 内 ， 他 在 任期 内 的 日期...
# 10     <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk...
# 11     他 说 ， 其他 其他 非洲 国家 的 领导人 不会 接受 他 所谓 的 “ <unk> ”...
# 12     如果 你 在 <unk> 中 使用 <unk> ， 请 确定 <unk> 中 的 <unk>...
# 13     如果 你 在 城市 生活 的 时候 ， 这 很 有用 。                  ...
# 14     我 说 ， 神 ， 我们 的 笔记本电脑 要 像 我们 的 <unk> 一样 。      ...
# ...
